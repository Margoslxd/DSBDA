# %% [markdown]
# ## Assignment 3
#
# Visualize the data using python libraries matplotlib, seaborn by plotting the graphs-
# 1. Pie Chart
# 2. Bar Graph
# 3. Box Plot
# 4. Histogram
# 5. Line Graph
# 6. Scatter Plot
# 7. Heatmap
# 8. Pair Plot
# 9. Word Cloud

# %% [markdown]
# ### Import python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# ### Read the Airquality.csv file

# %%
file= pd.read_csv(r"C:\Users\pranv\OneDrive\Desktop\dsbda\datasets\airquality.csv")
file
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     High
# 1             2   36.0    118.0   8.0    72      5    2     High
# 2             3   12.0    149.0  12.6    74      5    3      Low
# 3             4   18.0    313.0  11.5    62      5    4      NaN
# 4             5    NaN      NaN  14.3    56      5    5     High
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      Low
# 149         150    NaN    145.0  13.2    77      9   27      Low
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29   Medium
# 152         153   20.0    223.0  11.5    68      9   30      Low
#
# [153 rows x 8 columns]

# %% [markdown]
# ### Fill the NaN values with mean of respective column

# %%
file["Ozone"]= file["Ozone"].fillna(file["Ozone"].mean())
file["Solar.R"]= file["Solar.R"].fillna(file["Solar.R"].mean())

# %%
file
# Out:
#      Unnamed: 0     Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0             1  41.00000  190.000000   7.4    67      5    1     High
# 1             2  36.00000  118.000000   8.0    72      5    2     High
# 2             3  12.00000  149.000000  12.6    74      5    3      Low
# 3             4  18.00000  313.000000  11.5    62      5    4      NaN
# 4             5  42.12931  185.931507  14.3    56      5    5     High
# ..          ...       ...         ...   ...   ...    ...  ...      ...
# 148         149  30.00000  193.000000   6.9    70      9   26      Low
# 149         150  42.12931  145.000000  13.2    77      9   27      Low
# 150         151  14.00000  191.000000  14.3    75      9   28     High
# 151         152  18.00000  131.000000   8.0    76      9   29   Medium
# 152         153  20.00000  223.000000  11.5    68      9   30      Low
#
# [153 rows x 8 columns]

# %% [markdown]
# ## Pie Chart

# %%
plt.pie([file["Ozone"].mean(), file["Solar.R"].mean(), file["Wind"].mean(), file["Temp"].mean()], autopct="%1.2f%%", explode=[0.01, 0.01, 0.01,0.01], labels=["Ozone", "Solar.R", "Wind", "Temp"])
plt.plot()
# Out:
# []

# %% [markdown]
# ## Bar graph

# %%
def addlabels(): 
    for i in range(len(file.iloc[0:31, 4])):
        plt.text(i, file.iloc[0:31, 4][i], file.iloc[0:31, 4][i], ha="center")
        
y= np.arange(len(file.iloc[0:31,4]))
addlabels()
plt.bar(x=y, height= file.iloc[0:31, 4], tick_label=y, color="blue")
plt.title("Temperature for May")
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# ## Box plot

# %%
plt.boxplot(x= file[["Ozone","Solar.R", "Wind","Temp"]], labels=["Ozone","Solar.R", "Wind","Temp"])
plt.plot()
# Out:
# []

# %% [markdown]
# ## Histogram

# %%
plt.hist(x=file["Temp"], bins=20, color="purple", label="Temp")
plt.title("Temperature count")
plt.xlabel("Temperature")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Line graph

# %%
plt.plot(file.iloc[0: 30, 6], file.iloc[0:30, 4], color="orange")
plt.title("Temp of May month")
plt.xlabel("Day")
plt.ylabel("Temp")
# Out:
# Text(0, 0.5, 'Temp')

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(file.iloc[0:30, 6], file.iloc[0: 30, 3], color="red")
plt.title("Wind of May month")
plt.xlabel("Day")
plt.ylabel("Wind")
# Out:
# Text(0, 0.5, 'Wind')

# %% [markdown]
# ## Heatmap

# %%
seaborn.heatmap(data=file.iloc[0:38, [1,2,3,4]])
plt.show()

# %% [markdown]
# ## Pair plot

# %%
seaborn.pairplot(file.iloc[:, [1,2,3,4,7]], hue="Humidity")
plt.show()

# %% [markdown]
# ## Word cloud

# %%
with open("text.txt", "r") as file:
    text = file.read()
print(text)
# Out:
# some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords= set(STOPWORDS)

text = """some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here some random text here"""

wordcloud= WordCloud(width= 2500, height= 2500,
                    background_color= 'red',
                    stopwords= stopwords,
                    min_font_size= 16).generate(text)
plt.figure(figsize = (5, 5))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
